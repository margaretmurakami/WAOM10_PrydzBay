# %% [markdown]
# # Intro
#
# This file is to double check the output of our previous file and see if the floats were updated correctly

# %%
# Do not modify import block, all necessary imports are included
# Our regular libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import xarray as xr
# %matplotlib inline

# this is for density plotting
from matplotlib import colorbar, colors
import matplotlib as mpl
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
import math

# for the polygon intersections
import shapely.geometry as sg
import descartes

# for plotting
import time
import warnings
warnings.filterwarnings('ignore')

import sys
 
# appending a path
sys.path.append('/scratch/project_2000789/muramarg/miniconda3/lib/python3.10/site-packages/')
 
# importing required module
# import gsw
import netCDF4 as nc

# %% [markdown]
# # import the files if possible

# %%
# Open the NetCDF file
file_path = '/scratch/project_2000789/muramarg/waom_total_NTIMES70080/output_WAOM_check/ocean_flt.nc'
dataset = nc.Dataset(file_path, 'r')

# Assume the variable you are interested in is named 'your_variable'
# Replace 'your_variable' with the actual variable name
Xgrid = dataset.variables['Xgrid']
Ygrid = dataset.variables['Ygrid']
Zgrid = dataset.variables['Zgrid']

# %%
Xgrid[11,:].shape
Xgrid.shape
# Out:
# (70081, 40664)

# %%
# Open the NetCDF file
file_path = '/scratch/project_2000789/muramarg/waom_total/output_WAOM_check/ocean_flt.nc'
dataset = nc.Dataset(file_path, 'r')

# Assume the variable you are interested in is named 'your_variable'
# Replace 'your_variable' with the actual variable name
Xgrid_new = dataset.variables['Xgrid']
Ygrid_new = dataset.variables['Ygrid']
Zgrid_new = dataset.variables['Zgrid']

Xgrid_new[-1,:]
# Out:
# masked_array(data=[0.0, --, 0.0, ..., 359.8973388671875,
#                    501.93341064453125, 572.0398559570312],
#              mask=[False,  True, False, ..., False, False, False],
#        fill_value=1e+37,
#             dtype=float32)

# %%
Xgrid_new.shape
# Out:
# (124282, 3895)

# %% [markdown]
# ### Look at these in an example scatter plot

# %%
ds1  = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total/output_WAOM_check/ocean_avg_0001.nc")

# %%
plt.pcolormesh(ds1.temp.values[-1][0])

plt.scatter
# Out:
# <function matplotlib.pyplot.scatter(x: 'float | ArrayLike', y: 'float | ArrayLike', s: 'float | ArrayLike | None' = None, c: 'ArrayLike | Sequence[ColorType] | ColorType | None' = None, marker: 'MarkerType | None' = None, cmap: 'str | Colormap | None' = None, norm: 'str | Normalize | None' = None, vmin: 'float | None' = None, vmax: 'float | None' = None, alpha: 'float | None' = None, linewidths: 'float | Sequence[float] | None' = None, *, edgecolors: "Literal['face', 'none'] | ColorType | Sequence[ColorType] | None" = None, plotnonfinite: 'bool' = False, data=None, **kwargs) -> 'PathCollection'>

# %%
# read the first file
ds1  = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total_NTIMES70080/output_WAOM_check/ocean_avg_0001.nc")
ds1.ocean_time.values
# Out:
# array(['2026-12-30T19:15:00.000000000', '2027-01-07T09:45:00.000000000',
#        '2027-01-15T00:15:00.000000000', '2027-01-22T14:45:00.000000000'],
#       dtype='datetime64[ns]')

# %%
# read the most recent file to see how much time has passed
ds1  = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total/output_WAOM_check/ocean_avg_0043.nc")
ds1.ocean_time.values
# Out:
# array(['2032-06-29T07:15:00.000000000'], dtype='datetime64[ns]')

# %%
plt.pcolormesh(ds1.temp.values[-1][0])

# %% [markdown]
# # copy from filter_polynyas to see where the polynyas exist

# %%
# figure out where the polynya exists from the first run

# %%
numbers = np.arange(0, 104)

# Repeat the numbers to match the desired shape (20332)
repeated_numbers = np.tile(numbers, 391)

# Reshape the array to the desired shape (20332)
# this is the week in which each column has a particle released
array_shape_40664 = repeated_numbers.reshape(40664)

# Printing the array for verification
# week_release = array_shape_20332[pol_locs]

# %%
# we can choose from these files because even though random walk is differnt, ocean state the same
ds1  = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total_years1_2/output_WAOM_check/ocean_avg_0001.nc")
ds2  = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total_years1_2/output_WAOM_check/ocean_avg_0002.nc")
ds3  = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total_years1_2/output_WAOM_check/ocean_avg_0003.nc")
ds4  = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total_years1_2/output_WAOM_check/ocean_avg_0004.nc")
ds5  = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total_years1_2/output_WAOM_check/ocean_avg_0005.nc")
ds6  = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total_years1_2/output_WAOM_check/ocean_avg_0006.nc")
ds7  = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total_years1_2/output_WAOM_check/ocean_avg_0007.nc")
ds8  = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total_years1_2/output_WAOM_check/ocean_avg_0008.nc")
ds9  = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total_years1_2/output_WAOM_check/ocean_avg_0009.nc")
ds10 = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total_years1_2/output_WAOM_check/ocean_avg_0010.nc")
ds11 = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total_years1_2/output_WAOM_check/ocean_avg_0011.nc")
ds12 = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total_years1_2/output_WAOM_check/ocean_avg_0012.nc")
ds13  = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total_years1_2/output_WAOM_check/ocean_avg_0013.nc")
ds14  = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total_years1_2/output_WAOM_check/ocean_avg_0014.nc")
ds15  = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total_years1_2/output_WAOM_check/ocean_avg_0015.nc")
ds16  = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total_years1_2/output_WAOM_check/ocean_avg_0016.nc")
ds17  = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total_years1_2/output_WAOM_check/ocean_avg_0017.nc")
ds18  = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total_years1_2/output_WAOM_check/ocean_avg_0018.nc")
ds19  = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total_years1_2/output_WAOM_check/ocean_avg_0019.nc")
ds20  = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total_years1_2/output_WAOM_check/ocean_avg_0020.nc")
ds21  = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total_years1_2/output_WAOM_check/ocean_avg_0021.nc")
ds22 = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total_years1_2/output_WAOM_check/ocean_avg_0022.nc")
ds23 = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total_years1_2/output_WAOM_check/ocean_avg_0023.nc")
ds24 = xr.open_dataset("/scratch/project_2000789/muramarg/waom_total_years1_2/output_WAOM_check/ocean_avg_0024.nc")

# %%
ocean_time_values = np.array([],dtype=object)

for ds in (ds1,ds2,ds3,ds4,ds5,ds6,ds7,ds8,ds9,ds10,ds11,ds12,ds13,ds14,ds15,ds16,ds17,ds18,ds19,ds20,ds21,ds22,ds23,ds24):
    a = np.array(ds.ocean_time.values)
    ocean_time_values = np.append(ocean_time_values,a)

# %%
shfluxes = np.array([(ds1.shflux.values),
                     (ds2.shflux.values),
                     (ds3.shflux.values),
                     (ds4.shflux.values),
                     (ds5.shflux.values),
                     (ds6.shflux.values),
                     (ds7.shflux.values),
                     (ds8.shflux.values),
                     (ds9.shflux.values),
                     (ds10.shflux.values),
                     (ds11.shflux.values),
                     (ds12.shflux.values),
                     (ds13.shflux.values),
                     (ds14.shflux.values),
                     (ds15.shflux.values),
                     (ds16.shflux.values),
                     (ds17.shflux.values),
                     (ds18.shflux.values),
                     (ds19.shflux.values),
                     (ds20.shflux.values),
                     (ds21.shflux.values),
                     (ds22.shflux.values),
                     (ds23.shflux.values),])
shfluxes = shfluxes.reshape(23*4,560,630)

# %%
ssfluxes = np.array([(ds1.ssflux.values),
                     (ds2.ssflux.values),
                     (ds3.ssflux.values),
                     (ds4.ssflux.values),
                     (ds5.ssflux.values),
                     (ds6.ssflux.values),
                     (ds7.ssflux.values),
                     (ds8.ssflux.values),
                     (ds9.ssflux.values),
                     (ds10.ssflux.values),
                     (ds11.ssflux.values),
                     (ds12.ssflux.values),
                     (ds13.ssflux.values),
                     (ds14.ssflux.values),
                     (ds15.ssflux.values),
                     (ds16.ssflux.values),
                     (ds17.ssflux.values),
                     (ds18.ssflux.values),
                     (ds19.ssflux.values),
                     (ds20.ssflux.values),
                     (ds21.ssflux.values),
                     (ds22.ssflux.values),
                     (ds23.ssflux.values),])
ssfluxes = ssfluxes.reshape(23*4,560,630)
ssfluxes.shape
# Out:
# (92, 560, 630)

# %%
tt = 0
for i in range(24):
    tt += (ssfluxes[i].shape[0])
tt
# Out:
# 13440

# %%
ocean_time_values_datetime = np.array(ocean_time_values, dtype='datetime64[ns]')
start_date = ocean_time_values_datetime[0]
weekly_dates = pd.date_range(start=start_date, periods=92, freq='W').to_numpy()

# Function to find the closest date
def find_closest_date(target_date, date_array):
    index = np.abs(date_array - target_date).argmin()
    return (index)
    # return date_array[index]  # if we want to return the actual time

closest_ocean_times = np.array([find_closest_date(week_date, ocean_time_values_datetime) for week_date in weekly_dates])

# %%
closest_ocean_times.shape
# Out:
# (92,)

# %%
file_path = '/scratch/project_2000789/muramarg/floats_WAOM/text_files/points.txt'

# Initialize lists to store x and y values
x_values = []
y_values = []

with open(file_path) as inf:
    lines = inf.readlines()
    lines = lines[0].split(',')
    lines = np.array(lines).astype(float)
    
    i = 0
    for value in (lines):
        if i % 2 == 0:
            x_values.append(value)
        else:
            y_values.append(value)
        i += 1

# Convert lists to numpy arrays
x_array = np.array(x_values)
y_array = np.array(y_values)

# print("x array:", x_array)
# print("y array:", y_array)

# %%
closest_ocean_times.shape
# Out:
# (92,)

# %%
repeated_times = np.tile(closest_ocean_times, len(x_values))
max(repeated_times)
# Out:
# 84

# %%
x1 = np.repeat(x_array, 104)
y1 = np.repeat(y_array, 104)

# %%
shfluxes.shape
x_array.shape
repeated_times
# Out:
# array([ 1,  1,  2, ..., 82, 83, 84])

# %%
new_locs = np.array([])

total = 0
idate = 0
idx = 0
for i,j,time in zip(x1,y1,repeated_times):
    # get the closest date in which these values were released
    if time == 92:
        # maximum time which did not fit evenly into array
        myshflux = ds24.shflux.values[0]
        myssflux = ds24.ssflux.values[0]
    else: 
        myshflux = shfluxes[time]
        myssflux = ssfluxes[time]
    #print(myshflux.shape,myssflux.shape)
    
    if myshflux[int(j)][int(i)] < -120:
        #print(myssflux[int(j)][int(i)])
        if myssflux[int(j)][int(i)] > 1e-5 :#1e-5:
            #print(myssflux[int(j)][int(i)])
            total += 1
            new_locs = np.append(new_locs,idx)
    idx += 1

# %%
new_locs
# Out:
# array([  433.,   434.,   435., ..., 35950., 35961., 35965.])

# %%
new_locs.shape
# Out:
# (6813,)

# %%
# new_locs is now the indices in the last row of the floats file from years1_2 that should be copied to another run
new_locs = new_locs.astype(int)

# %%
new_locs
# Out:
# array([  433,   434,   435, ..., 35950, 35961, 35965])

# %% [markdown]
# # load the end of the floats file from years 1-2 and get the values that we need

# %%
# Open the NetCDF file
file_path = '/scratch/project_2000789/muramarg/waom_total/output_WAOM_check/ocean_flt.nc'
dataset = nc.Dataset(file_path, 'r')

# Assume the variable you are interested in is named 'your_variable'
# Replace 'your_variable' with the actual variable name
Xgrid = dataset.variables['Xgrid']
Ygrid = dataset.variables['Ygrid']
Zgrid = dataset.variables['Zgrid']

# %%
Xgridfinal = Xgrid[-1,:]
Ygridfinal = Ygrid[-1,:]
Zgridfinal = Zgrid[-1,:]

# %%
Xgridfinal_data = Xgridfinal.data
Ygridfinal_data = Ygridfinal.data
Zgridfinal_data = Zgridfinal.data

# %%
new_locs
# Out:
# array([  433,   434,   435, ..., 35950, 35961, 35965])

# %%
# Xgridfinal_sel = Xgridfinal_data[new_locs]
# test = Xgridfinal_sel != 0
# new_locs_final = new_locs[test]
# new_locs_final.shape

# %% [markdown]
# # make a new nc file with only the indices we want from the old file

# %%
# # our original file
# # Open the NetCDF file
# file_path = '/scratch/project_2000789/muramarg/waom_total_years1_2/output_WAOM_check/ocean_flt.nc'
# dataset = nc.Dataset(file_path, 'r')

# # Assume the variable you are interested in is named 'your_variable'
# # Replace 'your_variable' with the actual variable name
# Xgrid = dataset.variables['Xgrid']
# Ygrid = dataset.variables['Ygrid']
# Zgrid = dataset.variables['Zgrid']

# %%
# # we want to recreate the dataset with only the indices from new_locs_final
# # Define file paths
# input_file = '/scratch/project_2000789/muramarg/waom_total_years1_2/output_WAOM_check/ocean_flt.nc'
# output_file = '/scratch/project_2000789/muramarg/waom_total/output_WAOM_check/output_subset.nc'

# # Open the input NetCDF file
# with nc.Dataset(input_file, 'r') as src:
#     # Read the original variables
#     Xgrid = src.variables['Xgrid'][:]
#     Ygrid = src.variables['Ygrid'][:]
#     Zgrid = src.variables['Zgrid'][:]
    
#     # Assume new_locs_final is already defined as a 1D array of indices
#     #new_locs_final = np.array([index_list])  # Replace index_list with your actual indices
    
#     # Extract the subset of data
#     Xgrid_subset = Xgrid[:, new_locs_final]
#     Ygrid_subset = Ygrid[:, new_locs_final]
#     Zgrid_subset = Zgrid[:, new_locs_final]
    
# print("successfully read the floats file")

# %%
# # Create the output NetCDF file
# with nc.Dataset(output_file, 'w', format='NETCDF4') as dst:
#     # Create dimensions
#     dim0_size = Xgrid_subset.shape[0]
#     dim1_size = Xgrid_subset.shape[1]
    
#     dst.createDimension('dim0', dim0_size)
#     dst.createDimension('dim1', dim1_size)
    
#     # Create variables and write data to them
#     Xgrid_var = dst.createVariable('Xgrid', Xgrid_subset.dtype, ('dim0', 'dim1'))
#     Ygrid_var = dst.createVariable('Ygrid', Ygrid_subset.dtype, ('dim0', 'dim1'))
#     Zgrid_var = dst.createVariable('Zgrid', Zgrid_subset.dtype, ('dim0', 'dim1'))
    
#     Xgrid_var[:] = Xgrid_subset
#     Ygrid_var[:] = Ygrid_subset
#     Zgrid_var[:] = Zgrid_subset

# print(f'New NetCDF file {output_file} created successfully.')

# %%
# # let's double check that this ran now
# file_path = '/scratch/project_2000789/muramarg/waom_total/output_WAOM_check/output_subset.nc'
# dataset = nc.Dataset(file_path, 'r')

# %%
# Xgrid = dataset.variables['Xgrid']
# Xgrid[-1,:]

# %% [markdown]
# # write to file

# %%
path = "/scratch/project_2000789/muramarg/floats_WAOM/text_files/"

# write the above to a text file
firstline = 'POS = G, C, T, N,   Ft0,    Fx0,    Fy0,    Fz0,    Fdt,    Fdx,    Fdy,   Fdz'
secline = ''
G = "1"
C = "0"
T = "1"
N = "1"
Ft0 = '0.1d0'

# Fz0 = '-1.0d0'
Fdt = '7.0d0'
Fdx = '0.0d0'
Fdy = '0.0d0'
Fdz = '0.0d0'
lines = [firstline, secline]
for i,j,k in zip(X,Y,Z):
    # create the line to add to lines
    line = "\t"+G+"  "+C+"  "+T+"  "+N+"   "+Ft0+"   "+str(i)+"d0   "+str(j)+"d0   "+str(k)+"d0   "+"   "+Fdt+"   "+Fdx+"   "+Fdy+"   "+Fdz
    lines.append(line)
with open('points_NTIMES_70080.txt', 'w') as f:
    for line in lines:
        f.write(line)
        f.write('\n')
f.close()

# %%
# load the indices from the previous array so we can look at these from the bigger file
# new_locs
# Out:
# array([  433,   434,   435, ..., 35950, 35961, 35965])

# %% [markdown]
# ### Try to string together the two files

# %%
new_locs.shape   # these are the indices in the original floats file -- let's see if these match the other ones
# Out:
# (6813,)

# %%
# Open the NetCDF file
file_path = '/scratch/project_2000789/muramarg/waom_total_NTIMES70080/output_WAOM_check/ocean_flt.nc'
dataset = nc.Dataset(file_path, 'r')

# Assume the variable you are interested in is named 'your_variable'
# Replace 'your_variable' with the actual variable name
Xgrid = dataset.variables['Xgrid']
Ygrid = dataset.variables['Ygrid']
Zgrid = dataset.variables['Zgrid']

print(Xgrid.shape)

# get locations after two years
xoriglast = Xgrid[-1,:][new_locs]
yoriglast = Ygrid[-1,:][new_locs]
zoriglast = Zgrid[-1,:][new_locs]

xoriglast = xoriglast.data
yoriglast = yoriglast.data
zoriglast = zoriglast.data
# Out:
# (70081, 40664)

# %%
# compare to the newer version of the netcdf file
file_path = '/scratch/project_2000789/muramarg/waom_total_NTIMES140160/output_WAOM_check/ocean_flt.nc'
dataset = nc.Dataset(file_path, 'r')

# Assume the variable you are interested in is named 'your_variable'
# Replace 'your_variable' with the actual variable name
Xgrid = dataset.variables['Xgrid']
Ygrid = dataset.variables['Ygrid']
Zgrid = dataset.variables['Zgrid']
print(Xgrid.shape)

xorig_new = Xgrid[11,:]
yorig_new = Ygrid[11,:]
zorig_new = Zgrid[11,:]

xorig_new = xorig_new.data
yorig_new = yorig_new.data
zorig_new = zorig_new.data

xoriglast = xoriglast[:len(xorig_new)]
yoriglast = yoriglast[:len(yorig_new)]
zoriglast = zoriglast[:len(zorig_new)]
# Out:
# (79235, 3895)

# %%
# get locations after six years
file_path = '/scratch/project_2000789/muramarg/waom_total/output_WAOM_check/ocean_flt.nc'
dataset = nc.Dataset(file_path, 'r')

# Assume the variable you are interested in is named 'your_variable'
# Replace 'your_variable' with the actual variable name
Xgrid6 = dataset.variables['Xgrid']
Ygrid6 = dataset.variables['Ygrid']
Zgrid6 = dataset.variables['Zgrid']

print(Xgrid6.shape)

xorig_new6 = Xgrid[-1,:]
yorig_new6 = Ygrid[-1,:]
zorig_new6 = Zgrid[-1,:]

xorig_new6 = xorig_new6.data
yorig_new6 = yorig_new6.data
zorig_new6 = zorig_new6.data
# Out:
# (124282, 3895)

# %% [markdown]
# # plot these in an example scatter to see if they make sense

# %%
# after two years
plt.pcolormesh(ds1.temp.values[-1][0])
plt.scatter(xoriglast,yoriglast,s=.1,color="red")

# %%
# also plot at the end of the next two year simulation
plt.pcolormesh(ds1.temp.values[-1][0])
plt.scatter(Xgrid[-1,:].data,Ygrid[-1,:].data,s=.1,color="red")

# %%
# also plot at the end of the six years
plt.pcolormesh(ds1.temp.values[-1][0])

# set the beached or out of range values aside
xgrid6_data = Xgrid6[-1,:].data
xgrid6_data = xgrid6_data[xgrid6_data < 630]
xgrid6_data = xgrid6_data[xgrid6_data > 0]

ygrid6_data = Ygrid6[-1,:].data
ygrid6_data = ygrid6_data[ygrid6_data < 630]
ygrid6_data = ygrid6_data[ygrid6_data > 0]


plt.scatter(xgrid6_data,ygrid6_data,s=.1,color="red")

# %%
# I think we can just rerun from the current run if we switch the timesteps around
# 70080, 140160, 210240, 280320, 350400


# other thoughts 8/20 - I think we do not need to use waom_total_NTIMES140160 unless I want to specifically
# look at the end of the four year interval, regardless we should see how many timesteps per year per file

# %%
# 2 years:  70081 timesteps (0-2 years)
# 4 years:  79235 timesteps (2-4 years)
# 6 years: 124282 (2-6 years)
